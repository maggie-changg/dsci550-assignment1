# %%
import pandas as pd
merged_haunted_df = pd.read_csv("../data/merged_haunted_places_1.csv", sep=",")

# %%
# Create Weather DataFrame (Manually Extracted from Image statewide_weather)
weather_data = {
    "State": [
        "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", 
        "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", 
        "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine",
        "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi",
        "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey",
        "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio",
        "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
        "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", 
        "Washington", "West Virginia", "Wisconsin", "Wyoming"
    ],
    "avg_temp_rank": [127, 78, 115, 126, 118, 93, 128, 127, 126, 127, 123, 99, 
                      127, 125, 118, 126, 125, 129, 128, 128, 129, 123, 115, 127, 
                      125, 105, 125, 92, 128, 129, 118, 128, 127, 111, 126, 129, 
                      116, 128, 126, 119, 127, 129, 123, 128, 127, 122, 126, 129, 126],
    "avg_precip_rank": [126, 58, 114, 89, 103, 92, 124, 122, 101, 110, 56, 119, 
                        121, 103, 111, 89, 109, 26, 125, 124, 123, 121, 110, 70, 
                        96, 119, 89, 111, 124, 123, 95, 125, 124, 102, 91, 95, 
                        124, 121, 124, 119, 85, 8, 111, 125, 124, 124, 109, 92, 119],
    "precip_category": [
        "Above Average", "Much Below Average", "Near Average", "Below Average", 
        "Above Average", "Below Average", "Much Above Average", "Above Average", 
        "Above Average", "Above Average", "Below Average", "Near Average",
        "Above Average", "Near Average", "Above Average", "Below Average", 
        "Above Average", "Record Wettest", "Much Above Average", "Much Above Average", 
        "Much Above Average", "Above Average", "Near Average", "Below Average", 
        "Near Average", "Much Above Average", "Below Average", "Above Average", 
        "Much Above Average", "Much Above Average", "Near Average", "Much Above Average", 
        "Much Above Average", "Near Average", "Near Average", "Near Average", 
        "Much Above Average", "Above Average", "Much Above Average", 
        "Much Above Average", "Above Average", "Record Driest", "Above Average", 
        "Much Above Average", "Much Above Average", "Much Above Average", 
        "Above Average", "Below Average", "Near Average"
    ]
}

# %%
#Check the Length of Each List
for key, value in weather_data.items():
    print(f"{key}: {len(value)}")
min_length = max(len(lst) for lst in weather_data.values())  # Ensure all lists match the longest one

# Add missing values to short lists
for key, value in weather_data.items():
    while len(value) < min_length:
        weather_data[key].append(None)  # Use None or 0 if numerical
        
weather_df = pd.DataFrame(weather_data)
print(weather_df.head())  # Check the first few rows
# Out:
# State: 50
# avg_temp_rank: 49
# avg_precip_rank: 49
# precip_category: 49
#         State  avg_temp_rank  avg_precip_rank     precip_category
# 0     Alabama          127.0            126.0       Above Average
# 1      Alaska           78.0             58.0  Much Below Average
# 2     Arizona          115.0            114.0        Near Average
# 3    Arkansas          126.0             89.0       Below Average
# 4  California          118.0            103.0       Above Average

# %%
print(repr(merged_haunted_df.columns.tolist()))
print(repr(weather_df.columns.tolist()))
# Out:
# ['city', 'country', 'description', 'location', 'State', 'state_abbrev', 'longitude', 'latitude', 'city_longitude', 'city_latitude', 'Audio Evidence', 'Image/Video/Visual Evidence', 'Haunted Places Date', 'Haunted Places Witness Count', 'Time of Day', 'Apparition Type', 'Event Type', 'Deaths per Year', 'Average Potential Life Years Lost per Death', 'Deaths per 10,000 Adults', 'Percentage of Adults who Binge Drink 1+ Times per Month', 'Median Drinks per Binge', 'Top 25% Drinks per Binge', 'Median Binge per Month', 'Top 25% Binge per Month', 'Increase in Alcohol Deaths per Capita from 2015 to 2019', 'Male Proportion of Deaths', 'Percent Deaths from Chronic Causes', 'Percent Deaths from Acute Causes', 'Percent Deaths 35+', 'Percent Deaths under 21', 'Years of Life Lost per Year', 'Taxpayer Cost in 2010 (billions)', 'Inflation Adjusted Cost to 2022 (billions)', 'Inflation Adjusted Per Drink (2022)', 'avg_violent_crime', 'avg_murder_manslaughter', 'avg_property_crime']
# ...

# %%
# Merge Weather Data with Haunted Places
final_merged_df = merged_haunted_df.merge(weather_df, on="State", how="left")

# %%
# Save the final merged dataset
print("Final merged dataset shape:", final_merged_df.shape)
print(final_merged_df.head())
final_merged_df.to_csv("merged_haunted_places_2.csv", index=False, header=True)
test_df = pd.read_csv("merged_haunted_places_2.csv")
# Out:
# Final merged dataset shape: (10992, 41)
#       city        country                                        description  \
# 0      Ada  United States  Ada witch - Sometimes you can see a misty blue...
# 1  Addison  United States  A little girl was killed suddenly while waitin...
# 2   Adrian  United States  If you take Gorman Rd. west towards Sand Creek...
# 3   Adrian  United States  In the 1970's, one room, room 211, in the old ...
# 4   Albion  United States  Kappa Delta Sorority - The Kappa Delta Sororit...
#
#                    location     State state_abbrev  longitude   latitude  \
# 0              Ada Cemetery  Michigan           MI -85.504893  42.962106
# 1           North Adams Rd.  Michigan           MI -84.381843  41.971425
# 2             Ghost Trestle  Michigan           MI -84.035656  41.904538
# 3  Siena Heights University  Michigan           MI -84.017565  41.905712
# 4            Albion College  Michigan           MI -84.745177  42.244006
#
# ...

# %%
# Display updated dataset
print(final_merged_df.head())
# Out:
#       city        country                                        description  \
# 0      Ada  United States  Ada witch - Sometimes you can see a misty blue...
# 1  Addison  United States  A little girl was killed suddenly while waitin...
# 2   Adrian  United States  If you take Gorman Rd. west towards Sand Creek...
# 3   Adrian  United States  In the 1970's, one room, room 211, in the old ...
# 4   Albion  United States  Kappa Delta Sorority - The Kappa Delta Sororit...
#
#                    location     State state_abbrev  longitude   latitude  \
# 0              Ada Cemetery  Michigan           MI -85.504893  42.962106
# 1           North Adams Rd.  Michigan           MI -84.381843  41.971425
# 2             Ghost Trestle  Michigan           MI -84.035656  41.904538
# 3  Siena Heights University  Michigan           MI -84.017565  41.905712
# 4            Albion College  Michigan           MI -84.745177  42.244006
#
# ...
